# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

#Create lists to save values
cities_clean=[]
lats=[]
lngs=[]
temp=[]
humid=[]
cloud=[]
wind=[]
record=0
print("Beginning Data Retrieval")
print("-------------------------")

for city in cities:
    try: 
        weather_data=requests.get(url+city.replace(" ", "%20")).json()
        record= record + 1
        print("Processing record" + str(record) + "|" + city)
        print(url + city.replace(" ", "20%")) 
        temp.append(weather_data["main"]["temp"])
        humid.append(weather_data["main"]["humidity"])
        cloud.append(weather_data["clouds"]["all"])
        wind.append(weather_data["wind"]["speed"])
        cities_clean.append(weather_data["name"])
        lats.append(weather_data["coord"]["lat"])
        lngs.append(weather_data["coord"]["lat"])
        
    except KeyError:
        print(f"Sorry we don't have data for that")
        

print("---------------------------")
print("Data retrieval is complete.")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing record1|san joaquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%joaquin
# Processing record2|henderson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=henderson
# Processing record3|hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hilo
# Processing record4|albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=albany
# Processing record5|brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=brae
# Processing record6|nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nizhneyansk
# Sorry we don't have data for that
# Processing record7|kita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kita
# Processing record8|iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=iranshahr
# Processing record9|tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tasiilaq
# Processing record10|belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=belushya20%guba
# Sorry we don't have data for that
# Processing record11|provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=provideniya
# Processing record12|inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=inta
# Processing record13|nadvoitsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nadvoitsy
# Processing record14|okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=okhotsk
# Processing record15|busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=busselton
# Processing record16|yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yellowknife
# Processing record17|lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lavrentiya
# Processing record18|tawkar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tawkar
# Sorry we don't have data for that
# Processing record19|atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=atambua
# Processing record20|kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kodiak
# Processing record21|ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ushuaia
# Processing record22|turangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=turangi
# Processing record23|mokhotlong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mokhotlong
# Processing record24|matanzas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=matanzas
# Processing record25|itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=itarema
# Processing record26|kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kavieng
# Processing record27|mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mar20%del20%plata
# Processing record28|chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=chuy
# Processing record29|san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%patricio
# Processing record30|rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rikitea
# Processing record31|longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=longyearbyen
# Processing record32|rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rocha
# Processing record33|qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=qaanaaq
# Processing record34|hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hobart
# Processing record35|cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cabo20%san20%lucas
# Processing record36|bina-etawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bina-etawa
# Sorry we don't have data for that
# Processing record37|narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=narsaq
# Processing record38|tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tommot
# Processing record39|punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=punta20%arenas
# Processing record40|castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=castro
# Processing record41|barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=barrow
# Processing record42|grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=grindavik
# Processing record43|carora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=carora
# Processing record44|balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=balkhash
# Processing record45|tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tuktoyaktuk
# Processing record46|butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=butaritari
# Processing record47|cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cape20%town
# Processing record48|mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mahebourg
# Processing record49|jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=jamestown
# Processing record50|atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=atuona
# Processing record51|anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=anadyr
# Processing record52|severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=severo-kurilsk
# Processing record53|awka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=awka
# Processing record54|kharp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kharp
# Processing record55|kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kjollefjord
# Processing record56|east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=east20%london
# Processing record57|khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=khatanga
# Processing record58|cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cherskiy
# Processing record59|bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bredasdorp
# Processing record60|araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=araouane
# Processing record61|usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=usinsk
# Processing record62|hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hermanus
# Processing record63|ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ahipara
# Processing record64|umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=umm20%lajj
# Processing record65|yusva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yusva
# Sorry we don't have data for that
# Processing record66|san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%quintin
# Processing record67|pavlohrad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pavlohrad
# Processing record68|comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=comodoro20%rivadavia
# Processing record69|flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=flinders
# Processing record70|russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=russell
# Processing record71|arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=arraial20%do20%cabo
# Processing record72|tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tiksi
# Processing record73|nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nishihara
# Processing record74|mata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mata
# Processing record75|faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=faanui
# Processing record76|illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=illoqqortoormiut
# Sorry we don't have data for that
# Processing record77|nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nizwa
# Processing record78|moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=moron
# Processing record79|mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mataura
# Processing record80|tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tiznit
# Processing record81|upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=upernavik
# Processing record82|new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=new20%norfolk
# Processing record83|zhelyabovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=zhelyabovka
# Processing record84|faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=faya
# Processing record85|arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=arlit
# Processing record86|hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hasaki
# Processing record87|kajaani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kajaani
# Processing record88|kalanguy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kalanguy
# Processing record89|nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nouadhibou
# Processing record90|tibacuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tibacuy
# Processing record91|hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hithadhoo
# Processing record92|torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=torbay
# Processing record93|lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lebu
# Processing record94|taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=taolanaro
# Sorry we don't have data for that
# Processing record95|zinder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=zinder
# Processing record96|kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kodinsk
# Processing record97|morgan city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=morgan20%city
# Processing record98|tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tura
# Processing record99|dovolnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dovolnoye
# Processing record100|mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mys20%shmidta
# Sorry we don't have data for that
# Processing record101|kyra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kyra
# Sorry we don't have data for that
# Processing record102|esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=esperance
# Processing record103|samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=samusu
# Sorry we don't have data for that
# Processing record104|geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=geraldton
# Processing record105|port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=port20%elizabeth
# Processing record106|walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=walvis20%bay
# Processing record107|le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=le20%port
# Processing record108|hellvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hellvik
# Processing record109|georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=georgetown
# Processing record110|riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=riyadh
# Processing record111|berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=berlevag
# Processing record112|volsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=volsk
# Processing record113|olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=olafsvik
# Sorry we don't have data for that
# Processing record114|pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pevek
# Processing record115|tougue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tougue
# Processing record116|vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vila
# Processing record117|mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mezen
# Processing record118|alleroy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=alleroy
# Processing record119|fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=fortuna
# Processing record120|yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yulara
# Processing record121|puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=puerto20%ayora
# Processing record122|jabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=jabiru
# Sorry we don't have data for that
# Processing record123|nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nuuk
# Processing record124|maralal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=maralal
# Processing record125|avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=avarua
# Processing record126|hengyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hengyang
# Processing record127|codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=codrington
# Processing record128|kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kiunga
# Processing record129|egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=egvekinot
# Processing record130|kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kapaa
# Processing record131|san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%jose
# Processing record132|izumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=izumo
# Processing record133|lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lompoc
# Processing record134|soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=soyo
# Processing record135|zalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=zalantun
# Processing record136|fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=fukue
# Processing record137|unye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=unye
# Sorry we don't have data for that
# Processing record138|kutoarjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kutoarjo
# Processing record139|lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lasa
# Processing record140|lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lata
# Processing record141|dubti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dubti
# Processing record142|bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bluff
# Processing record143|mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mackay
# Processing record144|chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=chokurdakh
# Processing record145|norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=norman20%wells
# Processing record146|vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vrangel
# Processing record147|barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=barentsburg
# Sorry we don't have data for that
# Processing record148|khorixas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=khorixas
# Processing record149|vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vaini
# Processing record150|gazni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=gazni
# Sorry we don't have data for that
# Processing record151|tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tilichiki
# Processing record152|chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=chiredzi
# Processing record153|yantai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yantai
# Processing record154|shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=shimoda
# Processing record155|los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=los20%llanos20%de20%aridane
# Processing record156|leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=leshukonskoye
# Processing record157|sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sorong
# Processing record158|the pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=the20%pas
# Processing record159|ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ostrovnoy
# Processing record160|pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pangai
# Processing record161|sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sangar
# Processing record162|ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ponta20%do20%sol
# Processing record163|ovca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ovca
# Processing record164|port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=port20%alfred
# Processing record165|ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ribeira20%grande
# Processing record166|pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pochutla
# Processing record167|sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sentyabrskiy
# Sorry we don't have data for that
# Processing record168|pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pisco
# Processing record169|kamsack
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kamsack
# Processing record170|san vicente de canete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%vicente20%de20%canete
# Processing record171|rafai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rafai
# Processing record172|avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=avera
# Processing record173|praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=praia20%da20%vitoria
# Processing record174|tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tuatapere
# Processing record175|general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=general20%roca
# Processing record176|buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=buchanan
# Processing record177|nikko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nikko
# Processing record178|innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=innisfail
# Processing record179|road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=road20%town
# Processing record180|sulangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sulangan
# Processing record181|laela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=laela
# Processing record182|arucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=arucas
# Processing record183|emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=emba
# Processing record184|kashirskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kashirskoye
# Processing record185|christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=christchurch
# Processing record186|mazamari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mazamari
# Processing record187|warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=warrnambool
# Processing record188|bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bambous20%virieux
# Processing record189|kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kudahuvadhoo
# Processing record190|sarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sarkand
# Processing record191|zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=zhuhai
# Processing record192|maputo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=maputo
# Processing record193|abhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=abhar
# Processing record194|vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vestmannaeyjar
# Processing record195|honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=honiara
# Processing record196|ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ruteng
# Processing record197|salitrillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=salitrillo
# Processing record198|antigonish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=antigonish
# Processing record199|grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=grand20%river20%south20%east
# Sorry we don't have data for that
# Processing record200|hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hambantota
# Processing record201|ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ixtapa
# Processing record202|sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sawakin
# Processing record203|mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mount20%isa
# Processing record204|vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vila20%velha
# Processing record205|srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=srednekolymsk
# Processing record206|zhaotong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=zhaotong
# Processing record207|fatezh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=fatezh
# Processing record208|katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=katsuura
# Processing record209|avila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=avila
# Processing record210|barcelona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=barcelona
# Processing record211|garliava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=garliava
# Processing record212|san alberto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%alberto
# Processing record213|saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=saint20%anthony
# Processing record214|marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=marcona
# Sorry we don't have data for that
# Processing record215|champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=champerico
# Processing record216|lang son
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lang20%son
# Processing record217|bacolod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bacolod
# Processing record218|dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dikson
# Processing record219|rotenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rotenburg
# Processing record220|tubruq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tubruq
# Sorry we don't have data for that
# Processing record221|churumuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=churumuco
# Sorry we don't have data for that
# Processing record222|astanajapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=astanajapura
# Processing record223|saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=saint-philippe
# Processing record224|kurmanayevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kurmanayevka
# Processing record225|bissau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bissau
# Processing record226|karmala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=karmala
# Processing record227|touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=touros
# Processing record228|samaipata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=samaipata
# Processing record229|cazaje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cazaje
# Sorry we don't have data for that
# Processing record230|yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yerbogachen
# Processing record231|puerto palomas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=puerto20%palomas
# Processing record232|clocolan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=clocolan
# Processing record233|cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cockburn20%town
# Processing record234|saiha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=saiha
# Processing record235|talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=talnakh
# Processing record236|shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=shenjiamen
# Processing record237|gavle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=gavle
# Processing record238|qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=qaqortoq
# Processing record239|nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nikolskoye
# Processing record240|bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bonavista
# Processing record241|maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=maragogi
# Processing record242|mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mehran
# Processing record243|haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=haibowan
# Sorry we don't have data for that
# Processing record244|sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sompeta
# Processing record245|inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=inhambane
# Processing record246|bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bilibino
# Processing record247|beihai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=beihai
# Processing record248|malwan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=malwan
# Sorry we don't have data for that
# Processing record249|requena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=requena
# Processing record250|bafq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bafq
# Processing record251|muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=muros
# Processing record252|campbellton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=campbellton
# Processing record253|souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=souillac
# Processing record254|la paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=la20%paz
# Processing record255|guanhaes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=guanhaes
# Processing record256|attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=attawapiskat
# Sorry we don't have data for that
# Processing record257|pangoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pangoa
# Processing record258|margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=margate
# Processing record259|chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=chipinge
# Processing record260|diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=diamantino
# Processing record261|ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ranong
# Processing record262|anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=anloga
# Processing record263|tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tahe
# Processing record264|kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kahului
# Processing record265|haridwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=haridwar
# Processing record266|flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=flin20%flon
# Processing record267|boda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=boda
# Processing record268|tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tezu
# Processing record269|deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=deputatskiy
# Processing record270|necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=necochea
# Processing record271|tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tecoanapa
# Processing record272|half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=half20%moon20%bay
# Processing record273|ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ilulissat
# Processing record274|santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=santiago
# Processing record275|matadi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=matadi
# Processing record276|barabinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=barabinsk
# Processing record277|carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=carutapera
# Processing record278|deniliquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=deniliquin
# Processing record279|ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ust-kamchatsk
# Sorry we don't have data for that
# Processing record280|ngukurr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ngukurr
# Sorry we don't have data for that
# Processing record281|garden city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=garden20%city
# Processing record282|xunchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=xunchang
# Processing record283|cananeia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cananeia
# Processing record284|guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=guerrero20%negro
# Processing record285|kembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kembe
# Sorry we don't have data for that
# Processing record286|mishelevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mishelevka
# Processing record287|staryy nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=staryy20%nadym
# Processing record288|the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=the20%valley
# Processing record289|tambun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tambun
# Processing record290|yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yeniseysk
# Processing record291|guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=guarapari
# Processing record292|suwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=suwa
# Processing record293|dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dunedin
# Processing record294|yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=yatou
# Processing record295|viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=viedma
# Processing record296|kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kirakira
# Processing record297|kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kailua
# Processing record298|saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=saint-pierre
# Processing record299|lensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lensk
# Processing record300|havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=havre-saint-pierre
# Processing record301|nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nizhnevartovsk
# Processing record302|mandali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mandali
# Processing record303|bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bandarbeyla
# Processing record304|mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mandalgovi
# Processing record305|klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=klaksvik
# Processing record306|huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=huarmey
# Processing record307|mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mount20%gambier
# Processing record308|vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vardo
# Processing record309|puerto asis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=puerto20%asis
# Processing record310|dodoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dodoma
# Processing record311|bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bethel
# Processing record312|sheboygan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sheboygan
# Processing record313|chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=chicama
# Processing record314|liniere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=liniere
# Sorry we don't have data for that
# Processing record315|arica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=arica
# Processing record316|kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kruisfontein
# Processing record317|dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dingle
# Processing record318|pinega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pinega
# Processing record319|orocue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=orocue
# Processing record320|akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=akyab
# Sorry we don't have data for that
# Processing record321|khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=khonuu
# Sorry we don't have data for that
# Processing record322|cantagalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cantagalo
# Processing record323|labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=labuhan
# Processing record324|steamboat springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=steamboat20%springs
# Processing record325|rani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rani
# Processing record326|bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bilma
# Processing record327|vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vao
# Processing record328|havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=havelock
# Processing record329|san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=san20%cristobal
# Processing record330|xiongshi
# ...
# Processing record517|hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hobyo
# Processing record518|gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=gazanjyk
# Processing record519|bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bathsheba
# Processing record520|coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=coos20%bay
# Processing record521|broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=broken20%hill
# Processing record522|morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=morro20%bay
# Processing record523|whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=whitehorse
# Processing record524|porto belo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=porto20%belo
# Processing record525|aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=aykhal
# Processing record526|jizan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=jizan
# Processing record527|ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ponta20%delgada
# Processing record528|ust-kut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ust-kut
# Processing record529|zyryanskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=zyryanskoye
# Processing record530|kibakwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kibakwe
# Processing record531|grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=grand20%gaube
# Processing record532|platteville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=platteville
# Processing record533|chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=chernyshevskiy
# Processing record534|havre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=havre
# Processing record535|ovre ardal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ovre20%ardal
# Processing record536|bandipur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bandipur
# Processing record537|tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tazovskiy
# Processing record538|constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=constitucion
# Processing record539|lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lakes20%entrance
# Processing record540|uarini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=uarini
# Processing record541|salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=salinopolis
# Processing record542|coleraine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=coleraine
# Processing record543|khorramshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=khorramshahr
# Processing record544|varzea alegre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=varzea20%alegre
# Sorry we don't have data for that
# Processing record545|rapar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rapar
# Processing record546|takarazuka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=takarazuka
# Processing record547|tongliao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tongliao
# Processing record548|praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=praya
# Processing record549|palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=palmer
# Processing record550|tamarindo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tamarindo
# Processing record551|kashin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kashin
# Processing record552|conceicao das alagoas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=conceicao20%das20%alagoas
# Processing record553|kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kasongo-lunda
# Processing record554|axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=axim
# Processing record555|sangin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sangin
# Processing record556|nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=nurota
# Processing record557|ihosy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ihosy
# Processing record558|hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=hofn
# Processing record559|bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bengkulu
# Sorry we don't have data for that
# Processing record560|mastic beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mastic20%beach
# Processing record561|pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=pathein
# Processing record562|xinmin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=xinmin
# Processing record563|norrtalje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=norrtalje
# Processing record564|rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=rio20%gallegos
# Processing record565|garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=garowe
# Processing record566|kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kamenka
# Processing record567|felanitx
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=felanitx
# Processing record568|carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=carballo
# Processing record569|ngorongoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ngorongoro
# Processing record570|suruc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=suruc
# Processing record571|mafeteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=mafeteng
# Processing record572|greenwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=greenwood
# Processing record573|tynda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tynda
# Processing record574|unity
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=unity
# Processing record575|umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=umzimvubu
# Sorry we don't have data for that
# Processing record576|bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bintulu
# Processing record577|birjand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=birjand
# Processing record578|burica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=burica
# Sorry we don't have data for that
# Processing record579|jilotzingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=jilotzingo
# Processing record580|kerki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kerki
# Sorry we don't have data for that
# Processing record581|bamenda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=bamenda
# Processing record582|burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=burnie
# Processing record583|port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=port20%moresby
# Processing record584|lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lorengau
# Processing record585|gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=gorontalo
# Processing record586|manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=manokwari
# Processing record587|guhagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=guhagar
# Processing record588|sassandra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sassandra
# Processing record589|kurri kurri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kurri20%kurri
# Processing record590|qujing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=qujing
# Processing record591|kingaroy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kingaroy
# Processing record592|melfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=melfort
# Processing record593|awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=awjilah
# Processing record594|tawzar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=tawzar
# Sorry we don't have data for that
# Processing record595|grafton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=grafton
# Processing record596|ravar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ravar
# Processing record597|kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kropotkin
# Processing record598|dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dandong
# Processing record599|akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=akdepe
# Processing record600|vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=vanimo
# Processing record601|halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=halalo
# Sorry we don't have data for that
# Processing record602|sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sorvag
# Sorry we don't have data for that
# Processing record603|kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kieta
# Processing record604|leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=leningradskiy
# Processing record605|saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=saint-leu
# Processing record606|banff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=banff
# Processing record607|diego de almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=diego20%de20%almagro
# Processing record608|dalmatovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=dalmatovo
# Processing record609|lianran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lianran
# Processing record610|sug-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sug-aksy
# Sorry we don't have data for that
# Processing record611|husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=husavik
# Processing record612|sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=sinnamary
# Processing record613|surgut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=surgut
# Processing record614|todos santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=todos20%santos
# Processing record615|soledade
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=soledade
# Processing record616|adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=adrar
# Processing record617|cortes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=cortes
# Processing record618|lanzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=lanzhou
# Processing record619|ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=ayr
# Processing record620|kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=kununurra
# Processing record621|thung song
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=thung20%song
# Processing record622|terney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=terney
# Processing record623|katsiveli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=katsiveli
# Sorry we don't have data for that
# Processing record624|malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=malanje
# Processing record625|solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5428a008027faaad44a664e99ef43182&q=solnechnyy
# ---------------------------
# Data retrieval is complete.
# ---------------------------

# %%
weather_data_df=pd.DataFrame({"City": cities_clean, 
                              "Latitude": lats, 
                              "Longitude": lngs,
                              "Temperature": temp, 
                              "Humidity": humid, 
                              "Cloudiness": cloud, 
                              "Wind Speeds":wind})

weather_data_df.head()
# Out:
#           City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0  San Joaquin     10.59      10.59        76.79        88          56
# 1    Henderson     36.04      36.04        54.52        87          90
# 2         Hilo     19.71      19.71        80.06        71          40
# 3       Albany     42.65      42.65        36.10        72          90
# 4         Brae     60.40      60.40        48.20        87          92
#
#    Wind Speeds
# 0        12.88
# 1         6.93
# 2        10.29
# 3         4.70
# 4        23.04

# %%
#Lats vs Temp
plt.scatter(lats,temp)
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Temperature(F) vs. Latitude")
# Out:
# Text(0.5,1,'Temperature(F) vs. Latitude')

# %%
#Humidity (%) vs. Latitude
plt.scatter(lats,humid)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity (%) vs. Latitude")
# Out:
# Text(0.5,1,'Humidity (%) vs. Latitude')

# %%
#Cloudiness (%) vs. Latitude
plt.scatter(lats,cloud)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness (%) vs. Latitude")
# Out:
# Text(0.5,1,'Cloudiness (%) vs. Latitude')

# %%
#Wind Speed (mph) vs. Latitude
plt.scatter(lats,wind)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs. Latitude")
# Out:
# Text(0.5,1,'Wind Speed (mph) vs. Latitude')
